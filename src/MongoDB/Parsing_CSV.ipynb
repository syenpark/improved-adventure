# %% [markdown]
# # Mount Google Drive and Setting

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Path prefix
path = '/content/drive/My Drive/'

# Your coustom path before the project path
my_path = 'Colab Notebooks/'

# Our google drive project directory name
project_path = 'improved-adventure/'

# %% [markdown]
# # Parsing CSV with Strip function in Python
# strip() is to get rid of the extra whitespace.

# %%
import os

DATADIR = path + my_path + project_path + "data/"
DATAFILE = "beatles-discography.csv"

def parse_file(datafile):
  data = []
  
  with open(datafile, "rb") as f:
    for line in f:
      data.append(line)
      
  return data

# %%
def test():
    # a simple test of your implemetation
    datafile = os.path.join(DATADIR, DATAFILE)
    d = parse_file(datafile)
    firstline = {'Title': 'Please Please Me', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '22 March 1963', 'US Chart Position': '-', 'RIAA Certification': 'Platinum', 'BPI Certification': 'Gold'}
    tenthline = {'Title': '', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '10 July 1964', 'US Chart Position': '-', 'RIAA Certification': '', 'BPI Certification': 'Gold'}

    assert d[0] == firstline
    assert d[9] == tenthline

    
test()
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-41-fede1fbd241e> in <module>()
#      10
#      11
# ---> 12 test()
#
# <ipython-input-41-fede1fbd241e> in test()
#       6     tenthline = {'Title': '', 'UK Chart Position': '1', 'Label': 'Parlophone(UK)', 'Released': '10 July 1964', 'US Chart Position': '-', 'RIAA Certification': '', 'BPI Certification': 'Gold'}
#       7
# ----> 8     assert d[0] == firstline
#       9     assert d[9] == tenthline
#      10
#
# AssertionError:
